# %% [markdown]
# # Dirty documents noise removal
# ---

# %%
import numpy as np
import cv2
import os
from tqdm import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

import tensorflow as tf

# %%
path = '../data/noise_removal'
train_path = f'{path}/train'
train_cleaned_path = f'{path}/train_cleaned'
test_path = f'{path}/test'

# %%
train_img = sorted(os.listdir(train_path))
train_cleaned_img = sorted(os.listdir(train_cleaned_path))
test_img = sorted(os.listdir(test_path))

# %%
def process_image(path):

    image = cv2.imread(path)
    image = np.asarray(image, dtype= "float32")
    image = cv2.resize(image, (540, 420))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = image / 255.0
    image = np.reshape(image, (420, 540, 1))

    return image

def process_image_folder(folder_path):

    folder_images = sorted(os.listdir(folder_path))

    process_images = [
        process_image(folder_path + f'/{image}')
        for image in tqdm(folder_images)
    ]

    return process_images

# %%
train = process_image_folder(train_path)
train_cleaned = process_image_folder(train_cleaned_path)
test = process_image_folder(test_path)
# Out:
# 100%|██████████| 144/144 [00:01<00:00, 104.54it/s]
# 100%|██████████| 144/144 [00:01<00:00, 139.66it/s]
# 100%|██████████| 72/72 [00:00<00:00, 104.59it/s]

# %%
nrows = 4
ncols = 2

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 22))

image_idx = 0
for i in range(nrows):
    for j in range(ncols):
        ax[i,j].set_xticks([])
        ax[i,j].set_yticks([])
        if j == 1:
            ax[i,j].imshow(train_cleaned[image_idx][:,:,0], cmap='gray')
            ax[i,j].set_title('Cleaned image: {}'.format(train_img[i]))
        else:
            ax[i,j].imshow(train[image_idx][:,:,0], cmap='gray')
            ax[i,j].set_title('Noise image: {}'.format(train_img[i]))

    image_idx += 1

# %%
X_train = np.asarray(train)
y_train = np.asarray(train_cleaned)
X_test = np.asarray(test)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((122, 420, 540, 1), (22, 420, 540, 1), (122, 420, 540, 1), (22, 420, 540, 1))

# %%
def encoder(input_layer):

    x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
    x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
    x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    encoded = tf.keras.layers.Dropout(0.5)(x)

    return encoded

def decoder(x):

    x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = tf.keras.layers.UpSampling2D((2, 2))(x)
    x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = tf.keras.layers.UpSampling2D((2, 2))(x)
    x = tf.keras.layers.BatchNormalization()(x)
    decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    return decoded

def denoising(input_shape=(420, 540, 1)):

    input_layer = tf.keras.layers.Input(shape=input_shape)

    encoded = encoder(input_layer)
    decoded = decoder(encoded)

    model = tf.keras.models.Model(
        inputs=[input_layer],
        outputs=[decoded]
    )
    model.compile(
        optimizer='adam',
        loss='mean_squared_error',
        metrics=['mae']
    )

    return model

# %%
model = denoising()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 420, 540, 1)]     0
#
#  conv2d (Conv2D)             (None, 420, 540, 64)      640
#
#  max_pooling2d (MaxPooling2D  (None, 210, 270, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 210, 270, 128)     73856
#
#  max_pooling2d_1 (MaxPooling  (None, 105, 135, 128)    0
#  2D)
#
#  batch_normalization (BatchN  (None, 105, 135, 128)    512
#  ormalization)
#
#  dropout (Dropout)           (None, 105, 135, 128)     0
#
#  conv2d_2 (Conv2D)           (None, 105, 135, 128)     147584
#
#  up_sampling2d (UpSampling2D  (None, 210, 270, 128)    0
#  )
#
#  conv2d_3 (Conv2D)           (None, 210, 270, 64)      73792
#
#  up_sampling2d_1 (UpSampling  (None, 420, 540, 64)     0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 420, 540, 64)     256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 420, 540, 1)       577
#
# =================================================================
# Total params: 297,217
# Trainable params: 296,833
# Non-trainable params: 384
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, mode='auto', verbose=1)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=12,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 50s 1s/step - loss: 0.1606 - mae: 0.2915 - val_loss: 0.1790 - val_mae: 0.4114
# Epoch 2/100
# 11/11 [==============================] - 7s 669ms/step - loss: 0.0861 - mae: 0.2046 - val_loss: 0.1288 - val_mae: 0.3466
# Epoch 3/100
# 11/11 [==============================] - 7s 670ms/step - loss: 0.0626 - mae: 0.1701 - val_loss: 0.0985 - val_mae: 0.2920
# Epoch 4/100
# 11/11 [==============================] - 7s 669ms/step - loss: 0.0492 - mae: 0.1510 - val_loss: 0.0812 - val_mae: 0.2472
# Epoch 5/100
# 11/11 [==============================] - 7s 671ms/step - loss: 0.0402 - mae: 0.1338 - val_loss: 0.0730 - val_mae: 0.2083
# Epoch 6/100
# 11/11 [==============================] - 7s 671ms/step - loss: 0.0342 - mae: 0.1201 - val_loss: 0.0705 - val_mae: 0.1852
# Epoch 7/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0327 - mae: 0.1109 - val_loss: 0.0714 - val_mae: 0.1652
# Epoch 8/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0271 - mae: 0.1002 - val_loss: 0.0712 - val_mae: 0.1550
# Epoch 9/100
# 11/11 [==============================] - 7s 670ms/step - loss: 0.0254 - mae: 0.0939 - val_loss: 0.0714 - val_mae: 0.1465
# Epoch 10/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0218 - mae: 0.0905 - val_loss: 0.0730 - val_mae: 0.1386
# Epoch 11/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0195 - mae: 0.0842 - val_loss: 0.0730 - val_mae: 0.1336
# Epoch 12/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0177 - mae: 0.0796 - val_loss: 0.0730 - val_mae: 0.1300
# Epoch 13/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0167 - mae: 0.0767 - val_loss: 0.0743 - val_mae: 0.1263
# Epoch 14/100
# 11/11 [==============================] - 7s 671ms/step - loss: 0.0152 - mae: 0.0720 - val_loss: 0.0744 - val_mae: 0.1260
# Epoch 15/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0139 - mae: 0.0698 - val_loss: 0.0739 - val_mae: 0.1247
# Epoch 16/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0132 - mae: 0.0665 - val_loss: 0.0741 - val_mae: 0.1227
# Epoch 17/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0123 - mae: 0.0641 - val_loss: 0.0742 - val_mae: 0.1222
# Epoch 18/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0116 - mae: 0.0606 - val_loss: 0.0735 - val_mae: 0.1210
# Epoch 19/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0111 - mae: 0.0575 - val_loss: 0.0731 - val_mae: 0.1207
# Epoch 20/100
# 11/11 [==============================] - 8s 690ms/step - loss: 0.0108 - mae: 0.0555 - val_loss: 0.0726 - val_mae: 0.1200
# Epoch 21/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0105 - mae: 0.0539 - val_loss: 0.0721 - val_mae: 0.1195
# Epoch 22/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0101 - mae: 0.0522 - val_loss: 0.0704 - val_mae: 0.1179
# Epoch 23/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0097 - mae: 0.0506 - val_loss: 0.0694 - val_mae: 0.1176
# Epoch 24/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0095 - mae: 0.0496 - val_loss: 0.0688 - val_mae: 0.1165
# Epoch 25/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0092 - mae: 0.0484 - val_loss: 0.0669 - val_mae: 0.1155
# Epoch 26/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0090 - mae: 0.0476 - val_loss: 0.0660 - val_mae: 0.1161
# Epoch 27/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0087 - mae: 0.0467 - val_loss: 0.0632 - val_mae: 0.1141
# Epoch 28/100
# 11/11 [==============================] - 7s 671ms/step - loss: 0.0086 - mae: 0.0461 - val_loss: 0.0613 - val_mae: 0.1124
# Epoch 29/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0085 - mae: 0.0454 - val_loss: 0.0602 - val_mae: 0.1105
# Epoch 30/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0082 - mae: 0.0448 - val_loss: 0.0583 - val_mae: 0.1096
# Epoch 31/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0083 - mae: 0.0447 - val_loss: 0.0561 - val_mae: 0.1089
# Epoch 32/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0081 - mae: 0.0437 - val_loss: 0.0504 - val_mae: 0.1061
# Epoch 33/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0077 - mae: 0.0427 - val_loss: 0.0493 - val_mae: 0.1066
# Epoch 34/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0076 - mae: 0.0422 - val_loss: 0.0498 - val_mae: 0.1032
# Epoch 35/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0075 - mae: 0.0416 - val_loss: 0.0453 - val_mae: 0.0975
# Epoch 36/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0076 - mae: 0.0413 - val_loss: 0.0426 - val_mae: 0.0969
# Epoch 37/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0073 - mae: 0.0407 - val_loss: 0.0422 - val_mae: 0.0970
# Epoch 38/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0074 - mae: 0.0407 - val_loss: 0.0385 - val_mae: 0.0950
# Epoch 39/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0071 - mae: 0.0398 - val_loss: 0.0364 - val_mae: 0.0894
# Epoch 40/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0069 - mae: 0.0393 - val_loss: 0.0343 - val_mae: 0.0875
# Epoch 41/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0068 - mae: 0.0387 - val_loss: 0.0332 - val_mae: 0.0876
# Epoch 42/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0067 - mae: 0.0386 - val_loss: 0.0306 - val_mae: 0.0816
# Epoch 43/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0065 - mae: 0.0379 - val_loss: 0.0255 - val_mae: 0.0786
# Epoch 44/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0065 - mae: 0.0376 - val_loss: 0.0280 - val_mae: 0.0788
# Epoch 45/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0065 - mae: 0.0373 - val_loss: 0.0207 - val_mae: 0.0698
# Epoch 46/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0063 - mae: 0.0366 - val_loss: 0.0201 - val_mae: 0.0670
# Epoch 47/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0063 - mae: 0.0367 - val_loss: 0.0149 - val_mae: 0.0611
# Epoch 48/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0063 - mae: 0.0363 - val_loss: 0.0185 - val_mae: 0.0640
# Epoch 49/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.0061 - mae: 0.0361 - val_loss: 0.0144 - val_mae: 0.0570
# Epoch 50/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.0061 - mae: 0.0358 - val_loss: 0.0182 - val_mae: 0.0688
# Epoch 51/100
# 11/11 [==============================] - 7s 675ms/step - loss: 0.0062 - mae: 0.0357 - val_loss: 0.0123 - val_mae: 0.0569
# Epoch 52/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0060 - mae: 0.0353 - val_loss: 0.0112 - val_mae: 0.0559
# Epoch 53/100
# 11/11 [==============================] - 7s 675ms/step - loss: 0.0059 - mae: 0.0351 - val_loss: 0.0103 - val_mae: 0.0486
# Epoch 54/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0058 - mae: 0.0347 - val_loss: 0.0132 - val_mae: 0.0514
# Epoch 55/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0059 - mae: 0.0350 - val_loss: 0.0096 - val_mae: 0.0459
# Epoch 56/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0058 - mae: 0.0343 - val_loss: 0.0079 - val_mae: 0.0453
# Epoch 57/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0058 - mae: 0.0343 - val_loss: 0.0102 - val_mae: 0.0469
# Epoch 58/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0059 - mae: 0.0347 - val_loss: 0.0079 - val_mae: 0.0423
# Epoch 59/100
# 11/11 [==============================] - 7s 679ms/step - loss: 0.0056 - mae: 0.0338 - val_loss: 0.0074 - val_mae: 0.0422
# Epoch 60/100
# 11/11 [==============================] - 7s 675ms/step - loss: 0.0056 - mae: 0.0337 - val_loss: 0.0056 - val_mae: 0.0331
# Epoch 61/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0057 - mae: 0.0340 - val_loss: 0.0049 - val_mae: 0.0331
# Epoch 62/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0055 - mae: 0.0333 - val_loss: 0.0069 - val_mae: 0.0377
# Epoch 63/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0054 - mae: 0.0331 - val_loss: 0.0053 - val_mae: 0.0347
# Epoch 64/100
# 11/11 [==============================] - 7s 675ms/step - loss: 0.0054 - mae: 0.0331 - val_loss: 0.0047 - val_mae: 0.0319
# Epoch 65/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0054 - mae: 0.0328 - val_loss: 0.0039 - val_mae: 0.0289
# Epoch 66/100
# 11/11 [==============================] - 7s 675ms/step - loss: 0.0053 - mae: 0.0326 - val_loss: 0.0036 - val_mae: 0.0276
# Epoch 67/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0053 - mae: 0.0324 - val_loss: 0.0051 - val_mae: 0.0333
# Epoch 68/100
# 11/11 [==============================] - 7s 675ms/step - loss: 0.0052 - mae: 0.0324 - val_loss: 0.0037 - val_mae: 0.0257
# Epoch 69/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0052 - mae: 0.0321 - val_loss: 0.0036 - val_mae: 0.0264
# Epoch 70/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0052 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0252
# Epoch 71/100
# 11/11 [==============================] - 7s 679ms/step - loss: 0.0052 - mae: 0.0319 - val_loss: 0.0034 - val_mae: 0.0269
# Epoch 72/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0050 - mae: 0.0315 - val_loss: 0.0031 - val_mae: 0.0243
# Epoch 73/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0050 - mae: 0.0315 - val_loss: 0.0033 - val_mae: 0.0258
# Epoch 74/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0051 - mae: 0.0317 - val_loss: 0.0034 - val_mae: 0.0266
# Epoch 75/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0050 - mae: 0.0314 - val_loss: 0.0030 - val_mae: 0.0254
# Epoch 76/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0049 - mae: 0.0310 - val_loss: 0.0029 - val_mae: 0.0232
# Epoch 77/100
# 11/11 [==============================] - 7s 679ms/step - loss: 0.0050 - mae: 0.0312 - val_loss: 0.0034 - val_mae: 0.0250
# Epoch 78/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0049 - mae: 0.0309 - val_loss: 0.0029 - val_mae: 0.0244
# Epoch 79/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0048 - mae: 0.0306 - val_loss: 0.0030 - val_mae: 0.0239
# Epoch 80/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0048 - mae: 0.0306 - val_loss: 0.0027 - val_mae: 0.0231
# Epoch 81/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0049 - mae: 0.0308 - val_loss: 0.0028 - val_mae: 0.0236
# Epoch 82/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0047 - mae: 0.0304 - val_loss: 0.0028 - val_mae: 0.0235
# Epoch 83/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0047 - mae: 0.0304 - val_loss: 0.0036 - val_mae: 0.0245
# Epoch 84/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0048 - mae: 0.0306 - val_loss: 0.0028 - val_mae: 0.0223
# Epoch 85/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0047 - mae: 0.0303 - val_loss: 0.0029 - val_mae: 0.0233
# Epoch 86/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0046 - mae: 0.0300 - val_loss: 0.0032 - val_mae: 0.0242
# Epoch 87/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0047 - mae: 0.0302 - val_loss: 0.0030 - val_mae: 0.0242
# Epoch 88/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0046 - mae: 0.0299 - val_loss: 0.0027 - val_mae: 0.0235
# Epoch 89/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0046 - mae: 0.0298 - val_loss: 0.0032 - val_mae: 0.0236
# Epoch 90/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0046 - mae: 0.0298 - val_loss: 0.0026 - val_mae: 0.0219
# Epoch 91/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0045 - mae: 0.0296 - val_loss: 0.0028 - val_mae: 0.0234
# Epoch 92/100
# 11/11 [==============================] - 7s 676ms/step - loss: 0.0046 - mae: 0.0297 - val_loss: 0.0029 - val_mae: 0.0222
# Epoch 93/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0045 - mae: 0.0294 - val_loss: 0.0026 - val_mae: 0.0214
# Epoch 94/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0045 - mae: 0.0293 - val_loss: 0.0027 - val_mae: 0.0229
# Epoch 95/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0045 - mae: 0.0295 - val_loss: 0.0027 - val_mae: 0.0222
# Epoch 96/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0044 - mae: 0.0290 - val_loss: 0.0027 - val_mae: 0.0220
# Epoch 97/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0044 - mae: 0.0291 - val_loss: 0.0029 - val_mae: 0.0230
# Epoch 98/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0045 - mae: 0.0292 - val_loss: 0.0057 - val_mae: 0.0307
# Epoch 99/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.0044 - mae: 0.0290 - val_loss: 0.0028 - val_mae: 0.0221
# Epoch 100/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.0043 - mae: 0.0287 - val_loss: 0.0024 - val_mae: 0.0214

# %%
epoch_loss = history.history['loss']
epoch_val_loss = history.history['val_loss']
epoch_mae = history.history['mae']
epoch_val_mae = history.history['val_mae']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mae)), epoch_mae, 'b-', linewidth=2, label='Train MAE')
plt.plot(range(0,len(epoch_val_mae)), epoch_val_mae, 'r-', linewidth=2,label='Val MAE')
plt.title('Evolution of MAE on train & validation datasets over epochs')
plt.legend(loc='best')

plt.show()

# %%
test_cleaned = model.predict(X_test, batch_size=12)

# %%
nrows = 4
ncols = 2

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 22))

image_idx = 0
for i in range(nrows):
    for j in range(ncols):
      ax[i,j].set_xticks([])
      ax[i,j].set_yticks([])
      if j == 1:
          ax[i,j].imshow(test_cleaned[image_idx][:,:,0], cmap='gray')
          ax[i,j].set_title('Cleaned image: {}'.format(test_img[i]))
      else:
          ax[i,j].imshow(test[image_idx][:,:,0], cmap='gray')
          ax[i,j].set_title('Noise image: {}'.format(test_img[i]))

    image_idx += 1
